# %%
# %matplotlib inline

# %% [markdown]
# !pip install matplotlib scipy numpy pandas #pydata stack

# %% [markdown]
# # Pandas And Numpy

# %%
import pandas as pd 
import numpy as np

# %%
seris = pd.Series([1, 3, 5, np.nan, 6, 8])
seris
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
import random 

x = random.randint(1,2)
x_np  = np.random.rand(1)
x_np
# Out:
# array([0.01944514])

# %%
np.random.randn(6 ,1) @ np.random.randn(1 ,6)
# Out:
# array([[-0.01175938,  3.4989333 ,  2.57332983, -2.10868646,  2.87647217,
#          1.82333299],
#        [-0.00382059,  1.13679388,  0.83606784, -0.68510648,  0.93455796,
#          0.59239591],
#        [-0.00358376,  1.06632595,  0.78424141, -0.64263789,  0.87662629,
#          0.55567429],
#        [ 0.00952243, -2.83334045, -2.08381209,  1.7075566 , -2.32928846,
#         -1.47648516],
#        [-0.00671007,  1.99654006,  1.46837783, -1.20324585,  1.64135507,
#          1.04041919],
#        [-0.00401001,  1.19315475,  0.87751907, -0.71907323,  0.98089221,
#          0.62176618]])

# %%
import pandas as pd
dates = pd.date_range("20190520", periods=6)
dates
# Out:
# DatetimeIndex(['2019-05-20', '2019-05-21', '2019-05-22', '2019-05-23',
#                '2019-05-24', '2019-05-25'],
#               dtype='datetime64[ns]', freq='D')

# %%
nd_vec =  np.random.randn(6,4)

# %%
df2 = pd.DataFrame(nd_vec ,index=dates, columns=["epx", "sepx", "test2", "mid"] )
df2
# Out:
#                  epx      sepx     test2       mid
# 2019-05-20 -0.513815 -1.729490 -0.436757  0.177916
# 2019-05-21 -0.825593  0.481362  0.664201 -0.174025
# 2019-05-22 -0.878116  0.011745  0.300104 -0.148059
# 2019-05-23  0.539419  0.064962 -1.237084 -2.334954
# 2019-05-24  0.186646 -0.628217  0.202118 -0.513051
# 2019-05-25 -1.513153  1.559029 -0.337336  1.012556

# %%
list("nithin")
# Out:
# ['n', 'i', 't', 'h', 'i', 'n']

# %%
df = pd.DataFrame(nd_vec ,index=dates,  columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2019-05-20 -0.513815 -1.729490 -0.436757  0.177916
# 2019-05-21 -0.825593  0.481362  0.664201 -0.174025
# 2019-05-22 -0.878116  0.011745  0.300104 -0.148059
# 2019-05-23  0.539419  0.064962 -1.237084 -2.334954
# 2019-05-24  0.186646 -0.628217  0.202118 -0.513051
# 2019-05-25 -1.513153  1.559029 -0.337336  1.012556

# %%
df.dtypes
# Out:
# A    float64
# B    float64
# C    float64
# D    float64
# dtype: object

# %% [markdown]
# ## view data

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2019-05-20 -0.513815 -1.729490 -0.436757  0.177916
# 2019-05-21 -0.825593  0.481362  0.664201 -0.174025

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2019-05-23  0.539419  0.064962 -1.237084 -2.334954
# 2019-05-24  0.186646 -0.628217  0.202118 -0.513051
# 2019-05-25 -1.513153  1.559029 -0.337336  1.012556

# %%
df.T
# Out:
#    2019-05-20  2019-05-21  2019-05-22  2019-05-23  2019-05-24  2019-05-25
# A   -0.513815   -0.825593   -0.878116    0.539419    0.186646   -1.513153
# B   -1.729490    0.481362    0.011745    0.064962   -0.628217    1.559029
# C   -0.436757    0.664201    0.300104   -1.237084    0.202118   -0.337336
# D    0.177916   -0.174025   -0.148059   -2.334954   -0.513051    1.012556

# %%
df2["mid"]
# Out:
# 2019-05-20    0.177916
# 2019-05-21   -0.174025
# 2019-05-22   -0.148059
# 2019-05-23   -2.334954
# 2019-05-24   -0.513051
# 2019-05-25    1.012556
# Freq: D, Name: mid, dtype: float64

# %%
df.B
# Out:
# 2019-05-20   -1.729490
# 2019-05-21    0.481362
# 2019-05-22    0.011745
# 2019-05-23    0.064962
# 2019-05-24   -0.628217
# 2019-05-25    1.559029
# Freq: D, Name: B, dtype: float64

# %%
df.A
# Out:
# 2019-05-20   -0.513815
# 2019-05-21   -0.825593
# 2019-05-22   -0.878116
# 2019-05-23    0.539419
# 2019-05-24    0.186646
# 2019-05-25   -1.513153
# Freq: D, Name: A, dtype: float64

# %%
df['A']
# Out:
# 2019-05-20   -0.513815
# 2019-05-21   -0.825593
# 2019-05-22   -0.878116
# 2019-05-23    0.539419
# 2019-05-24    0.186646
# 2019-05-25   -1.513153
# Freq: D, Name: A, dtype: float64

# %%
df[0:4]
# Out:
#                    A         B         C         D
# 2019-05-20 -0.513815 -1.729490 -0.436757  0.177916
# 2019-05-21 -0.825593  0.481362  0.664201 -0.174025
# 2019-05-22 -0.878116  0.011745  0.300104 -0.148059
# 2019-05-23  0.539419  0.064962 -1.237084 -2.334954

# %%
dates[1:5]
# Out:
# DatetimeIndex(['2019-05-21', '2019-05-22', '2019-05-23', '2019-05-24'], dtype='datetime64[ns]', freq='D')

# %%
df.loc[dates[2:5], "D"]
# Out:
# 2019-05-22   -0.148059
# 2019-05-23   -2.334954
# 2019-05-24   -0.513051
# Freq: D, Name: D, dtype: float64

# %%
df.loc['20190520':'20190524', ['A', 'B']]
# Out:
#                    A         B
# 2019-05-20 -0.513815 -1.729490
# 2019-05-21 -0.825593  0.481362
# 2019-05-22 -0.878116  0.011745
# 2019-05-23  0.539419  0.064962
# 2019-05-24  0.186646 -0.628217

# %%
df.iloc[1]
# Out:
# A   -0.825593
# B    0.481362
# C    0.664201
# D   -0.174025
# Name: 2019-05-21 00:00:00, dtype: float64

# %%
df.iloc[1:5]
# Out:
#                    A         B         C         D
# 2019-05-21 -0.825593  0.481362  0.664201 -0.174025
# 2019-05-22 -0.878116  0.011745  0.300104 -0.148059
# 2019-05-23  0.539419  0.064962 -1.237084 -2.334954
# 2019-05-24  0.186646 -0.628217  0.202118 -0.513051

# %%
df.iloc[1:5, 0:3]
# Out:
#                    A         B         C
# 2019-05-21 -0.825593  0.481362  0.664201
# 2019-05-22 -0.878116  0.011745  0.300104
# 2019-05-23  0.539419  0.064962 -1.237084
# 2019-05-24  0.186646 -0.628217  0.202118

# %%
df.iloc[1:3,0:2]
# Out:
#           A         B
# 1  2.736632 -0.889280
# 2  0.100004 -0.791843

# %%
df.iloc[1:3,1:2]
# Out:
#                    B
# 2019-05-21 -0.142105
# 2019-05-22  0.342140

# %%
df.size
# Out:
# 24

# %%
df.A
# Out:
# 0   -0.293821
# 1    2.736632
# 2    0.100004
# 3    2.019771
# 4   -0.151741
# 5   -1.073628
# Name: A, dtype: float64

# %%
import os

from pathlib import Path
path = Path(".")

os.getcwd()
# Out:
# '/home/nithin/Documents/python-class-1/pydata'

# %%
ls {path/"data"}
# Out:
# Train.csv

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'pandas.ipynb',
#  'Numpy.ipynb',
#  'tmp',
#  'Train.csv',
#  'comp and std imports .ipynb']

# %%
df = pd.read_csv("Train.csv")

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121           3.0      2004
# 1  1139248      57000     117657       77         121           3.0      1996
# 2  1139249      10000     434808     7009         121           3.0      2001
# 3  1139251      38500    1026470      332         121           3.0      2001
# 4  1139253      11000    1057373    17311         121           3.0      2007
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                      68.0       Low  11/16/2006 0:00  ...
# 1                    4640.0       Low   3/26/2004 0:00  ...
# 2                    2838.0      High   2/26/2004 0:00  ...
# 3                    3486.0      High   5/19/2011 0:00  ...
# 4                     722.0    Medium   7/23/2009 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# ...

# %%
df.shape
# Out:
# (401125, 53)

# %%
df.T
# Out:
#                                                             0       \
# SalesID                                                    1139246
# SalePrice                                                    66000
# MachineID                                                   999089
# ModelID                                                       3157
# datasource                                                     121
# auctioneerID                                                     3
# YearMade                                                      2004
# MachineHoursCurrentMeter                                        68
# UsageBand                                                      Low
# saledate                                           11/16/2006 0:00
# fiModelDesc                                                   521D
# fiBaseModel                                                    521
# fiSecondaryDesc                                                  D
# ...

# %%
#lambda df: df['shield'] == 8

def reo(df):
    return  df['shield'] == 8

df.loc[reo(df)]

import math 


#list(map(lambda x : math.sin(x), range(10)))



def re_sin(x):
    return math.sin(x)

[re_sin(x) for x in  range(10)]
# Out:
# [0.0,
#  0.8414709848078965,
#  0.9092974268256817,
#  0.1411200080598672,
#  -0.7568024953079282,
#  -0.9589242746631385,
#  -0.27941549819892586,
#  0.6569865987187891,
#  0.9893582466233818,
#  0.4121184852417566]
