# %%
# %matplotlib inline

# %%
import wget

# %%
url = 'http://raw.githubusercontent.com/h2oai/h2o-tutorials/master/training/sessions/plano-tx/data_1024.csv'
data_path = wget.download(url)
# Out:
# 100% [..............................................................................] 85448 / 85448

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv(data_path, low_memory=False, sep="\t" , index_col=["Driver_ID"])

# %%
df.head()
# Out:
#             Distance_Feature  Speeding_Feature
# Driver_ID
# 3423311935             71.24              28.0
# 3423313212             52.53              25.0
# 3423313724             64.54              27.0
# 3423311373             55.69              22.0
# 3423310999             54.58              25.0

# %%
df.iloc[:,0]
# Out:
# Driver_ID
# 3423311935     71.24
# 3423313212     52.53
# 3423313724     64.54
# 3423311373     55.69
# 3423310999     54.58
#                ...
# 3423310685    160.04
# 3423312600    176.17
# 3423312921    170.91
# 3423313630    176.14
# 3423311533    168.03
# Name: Distance_Feature, Length: 4000, dtype: float64

# %%
df["Distance_Feature"]
# Out:
# Driver_ID
# 3423311935     71.24
# 3423313212     52.53
# 3423313724     64.54
# 3423311373     55.69
# 3423310999     54.58
#                ...
# 3423310685    160.04
# 3423312600    176.17
# 3423312921    170.91
# 3423313630    176.14
# 3423311533    168.03
# Name: Distance_Feature, Length: 4000, dtype: float64

# %%
df.describe(include="all")
# Out:
#        Distance_Feature  Speeding_Feature
# count       4000.000000       4000.000000
# mean          76.041523         10.721000
# std           53.469563         13.708543
# min           15.520000          0.000000
# 25%           45.247500          4.000000
# 50%           53.330000          6.000000
# 75%           65.632500          9.000000
# max          244.790000        100.000000

# %%
plt.plot(df["Distance_Feature"],df["Speeding_Feature"],  ".")

# %%
df.shape
# Out:
# (4000, 2)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(df.iloc[:, 0], df.iloc[:, 1],marker=".", c="r")

# %%
X= StandardScaler().fit_transform(df)  # this is scaling 
X.shape
# Out:
# (4000, 2)

# %%
X
# Out:
# array([[-0.0898104 ,  1.26061251],
#        [-0.43977285,  1.04174351],
#        [-0.215131  ,  1.18765617],
#        ...,
#        [ 1.77447381,  0.09331115],
#        [ 1.87229869, -0.41738319],
#        [ 1.72060465, -0.12555785]])

# %%
from scipy.spatial import Voronoi, voronoi_plot_2d

# compute Voronoi tesselation
vor = Voronoi(X)

# plot
voronoi_plot_2d(vor)

# colorize
for region in vor.regions:
    if not -1 in region:
        polygon = [vor.vertices[i] for i in region]
        plt.fill(*zip(*polygon))

# %%
X[0]
# Out:
# array([-0.0898104 ,  1.26061251])

# %%
kmeans = KMeans(n_clusters=2).fit(X)

# %%
y_pred = kmeans.predict(X)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_pred, marker=".")
plt.title("Incorrect Number of Blobs")
# Out:
# Text(0.5, 1.0, 'Incorrect Number of Blobs')

# %%
kmeans.predict(np.array([[-0.432537285,  0.04174351],
                     [-1.432537285,  2.04174351],
                     [-1.432537285,  6.04174351]]))
# Out:
# array([0, 0, 0])

# %%
y_pred_li = y_pred.tolist()
y_pred_li = set(y_pred_li)
y_pred_li
# Out:
# {0, 1}

# %%
dir(kmeans)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_test_data',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_tags',
#  '_transform',
#  'algorithm',
#  'cluster_centers_',
#  'copy_x',
#  'fit',
#  'fit_predict',
#  'fit_transform',
#  'get_params',
#  'inertia_',
#  'init',
#  'labels_',
#  'max_iter',
#  'n_clusters',
#  'n_init',
#  'n_iter_',
#  'n_jobs',
#  'precompute_distances',
#  'predict',
#  'random_state',
#  'score',
#  'set_params',
#  'tol',
#  'transform',
#  'verbose']

# %%
kmeans = KMeans(n_clusters=5).fit(X)
y_pred = kmeans.predict(X)
y_c= kmeans.cluster_centers_
plt.scatter(X[:, 0], X[:, 1], c=y_pred,marker="." )
plt.scatter(y_c[:, 0], y_c[:, 1], marker="X" , c="r")

plt.title("Incorrect Number of Blobs")
# Out:
# Text(0.5, 1.0, 'Incorrect Number of Blobs')

# %%
#Elbow 
sse = []
list_k = list(range(1, 10))

for k in list_k:
    km = KMeans(n_clusters=k)
    km.fit(X)
    sse.append(km.inertia_)

# Plot sse against k
plt.figure(figsize=(6, 6))
plt.plot(list_k, sse, '-o')
plt.xlabel(r'Number of clusters *k*')
plt.ylabel('Sum of squared distance');

# %%
from sklearn.datasets import make_moons
X, y = make_moons(200, noise=.05, random_state=0)

# %%
labels = KMeans(2, random_state=0).fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');

# %%
from sklearn.cluster import SpectralClustering
model = SpectralClustering(n_clusters=2, affinity='nearest_neighbors',
                           assign_labels='kmeans')
labels = model.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], c=labels,
            s=50, cmap='viridis');
# Out:
# C:\Users\jithi\Anaconda3\lib\site-packages\sklearn\manifold\spectral_embedding_.py:235: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
